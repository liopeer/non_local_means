# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from skimage.util import random_noise

from nlm import non_local_means

img = Image.open("cameraman.jpg")
img = np.array(img).astype(np.float32) / 255.0
img = img.mean(-1)
plt.imshow(img, cmap="gray")
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
noisy_img = random_noise(img, mode='gaussian', var=0.01).astype(np.float32)
plt.imshow(noisy_img, cmap="gray")
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
denoised_img = non_local_means(noisy_img, 256)
plt.imshow(denoised_img, cmap="gray")
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)
